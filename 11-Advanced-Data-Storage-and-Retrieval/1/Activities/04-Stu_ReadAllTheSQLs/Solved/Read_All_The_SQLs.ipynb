# %%
# Pandas
import pandas as pd

# SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# %%
# Create Engine and Pass in MySQL Connection
engine = create_engine("mysql://k5xunpkmojyzse51:ifagg1gp7e2xyapi@ffn96u87j5ogvehy.cbetxkdyhwsb.us-east-1.rds.amazonaws.com:3306/tq6h098h0ym00zp6")
#engine = create_engine("mysql://root:pw@localhost:3306/misc_db")
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     919                                 (self.host, self.port), self.connect_timeout,
# --> 920                                 **kwargs)
#     921                             break
#
# /anaconda3/envs/PythonData/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#
# /anaconda3/envs/PythonData/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in unique_connection(self)
#     344         """
# --> 345         return _ConnectionFairy._checkout(self)
#     346
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     783         if not fairy:
# --> 784             fairy = _ConnectionRecord.checkout(pool)
#     785
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1188                 with util.safe_reraise():
# -> 1189                     self._dec_overflow()
#    1190         else:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1185             try:
# -> 1186                 return self._create_connection()
#    1187             except:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     666             self.starttime = time.time()
# --> 667             connection = pool._invoke_creator(self)
#     668             pool.logger.debug("Created new connection %r", connection)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      89     from .connections import Connection
# ---> 90     return Connection(*args, **kwargs)
#      91
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, no_delay, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix)
#     698         else:
# --> 699             self.connect()
#     700
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     966                 if DEBUG: print(exc.traceback)
# --> 967                 raise exc
#     968
#
# OperationalError: (2003, "Can't connect to MySQL server on 'ffn96u87j5ogvehy.cbetxkdyhwsb.us-east-1.rds.amazonaws.com' (timed out)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-6-f2f725f5880c> in <module>()
#       2 engine = create_engine("mysql://k5xunpkmojyzse51:ifagg1gp7e2xyapi@ffn96u87j5ogvehy.cbetxkdyhwsb.us-east-1.rds.amazonaws.com:3306/tq6h098h0ym00zp6")
#       3 #engine = create_engine("mysql://root:pw@localhost:3306/misc_db")
# ----> 4 conn = engine.connect()
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in connect(self, **kwargs)
#    2100         """
#    2101
# -> 2102         return self._connection_cls(self, **kwargs)
#    2103
#    2104     def contextual_connect(self, close_with_result=False, **kwargs):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      88         else:
#      89             self.__connection = connection \
# ---> 90                 if connection is not None else engine.raw_connection()
#      91             self.__transaction = None
#      92             self.__savepoint_seq = 0
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    2186         """
#    2187         return self._wrap_pool_connect(
# -> 2188             self.pool.unique_connection, _connection)
#    2189
#    2190
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in unique_connection(self)
#     343
#     344         """
# --> 345         return _ConnectionFairy._checkout(self)
#     346
#     347     def _create_connection(self):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     782     def _checkout(cls, pool, threadconns=None, fairy=None):
#     783         if not fairy:
# --> 784             fairy = _ConnectionRecord.checkout(pool)
#     785
#     786             fairy._pool = pool
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     530     @classmethod
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#     534             dbapi_connection = rec.get_connection()
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1187             except:
#    1188                 with util.safe_reraise():
# -> 1189                     self._dec_overflow()
#    1190         else:
#    1191             return self._do_get()
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1184         if self._inc_overflow():
#    1185             try:
# -> 1186                 return self._create_connection()
#    1187             except:
#    1188                 with util.safe_reraise():
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     348         """Called by subclasses to create a new ConnectionRecord."""
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#     352     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     475         self.__pool = pool
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#     479
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     665         try:
#     666             self.starttime = time.time()
# --> 667             connection = pool._invoke_creator(self)
#     668             pool.logger.debug("Created new connection %r", connection)
#     669             self.connection = connection
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     104                         if connection is not None:
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#     108             creator = pop_kwarg('creator', connect)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     408
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#     412     def create_connect_args(self, url):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      88     """
#      89     from .connections import Connection
# ---> 90     return Connection(*args, **kwargs)
#      91
#      92 from . import connections as _orig_conn
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, no_delay, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix)
#     697             self._sock = None
#     698         else:
# --> 699             self.connect()
#     700
#     701     def _create_ssl_ctx(self, sslp):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     965                 exc.traceback = traceback.format_exc()
#     966                 if DEBUG: print(exc.traceback)
# --> 967                 raise exc
#     968
#     969             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on 'ffn96u87j5ogvehy.cbetxkdyhwsb.us-east-1.rds.amazonaws.com' (timed out)") (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
# Query All Records in the the City Table
census_data = pd.read_sql("SELECT * FROM Census_Data", conn)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     164
# --> 165         result = self._query(query)
#     166         self._executed = query
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/cursors.py in _query(self, q)
#     320         self._last_executed = q
# --> 321         conn.query(q)
#     322         self._do_get_result()
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     859         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 860         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     861         return self._affected_rows
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#    1060             result = MySQLResult(self)
# -> 1061             result.read()
#    1062         self._result = result
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in read(self)
#    1348         try:
# -> 1349             first_packet = self.connection._read_packet()
#    1350
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#    1017         packet = packet_type(buff, self.encoding)
# -> 1018         packet.check_error()
#    1019         return packet
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in check_error(self)
#     383             if DEBUG: print("errno =", errno)
# --> 384             err.raise_mysql_exception(self._data)
#     385
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     106     errorclass = error_map.get(errno, InternalError)
# --> 107     raise errorclass(errno, errval)
#
# ProgrammingError: (1146, "Table 'misc_db.census_data' doesn't exist")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-4-e365d7112c68> in <module>()
#       1 # Query All Records in the the City Table
# ----> 2 census_data = pd.read_sql("SELECT * FROM Census_Data", conn)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     414             sql, index_col=index_col, params=params,
#     415             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 416             chunksize=chunksize)
#     417
#     418
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1090         args = _convert_params(sql, params)
#    1091
# -> 1092         result = self.execute(*args)
#    1093         columns = result.keys()
#    1094
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#     981     def execute(self, *args, **kwargs):
#     982         """Simple passthrough to SQLAlchemy connectable"""
# --> 983         return self.connectable.execute(*args, **kwargs)
#     984
#     985     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     940         """
#     941         if isinstance(object, util.string_types[0]):
# --> 942             return self._execute_text(object, multiparams, params)
#     943         try:
#     944             meth = object._execute_on_connection
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1102             statement,
#    1103             parameters,
# -> 1104             statement, parameters
#    1105         )
#    1106         if self._has_events or self.engine._has_events:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     505
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#     509     def do_execute_no_params(self, cursor, statement, context=None):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     163         query = self.mogrify(query, args)
#     164
# --> 165         result = self._query(query)
#     166         self._executed = query
#     167         return result
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/cursors.py in _query(self, q)
#     319         conn = self._get_db()
#     320         self._last_executed = q
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     858                 sql = sql.encode(self.encoding, 'surrogateescape')
#     859         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 860         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     861         return self._affected_rows
#     862
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#    1059         else:
#    1060             result = MySQLResult(self)
# -> 1061             result.read()
#    1062         self._result = result
#    1063         if result.server_status is not None:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in read(self)
#    1347     def read(self):
#    1348         try:
# -> 1349             first_packet = self.connection._read_packet()
#    1350
#    1351             if first_packet.is_ok_packet():
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#    1016
#    1017         packet = packet_type(buff, self.encoding)
# -> 1018         packet.check_error()
#    1019         return packet
#    1020
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in check_error(self)
#     382             errno = self.read_uint16()
#     383             if DEBUG: print("errno =", errno)
# --> 384             err.raise_mysql_exception(self._data)
#     385
#     386     def dump(self):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     105         errval = data[3:].decode('utf-8', 'replace')
#     106     errorclass = error_map.get(errno, InternalError)
# --> 107     raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1146, "Table 'misc_db.census_data' doesn't exist") [SQL: 'SELECT * FROM Census_Data'] (Background on this error at: http://sqlalche.me/e/f405)

# %%
# Query All Records in the Zip Table
zip_data = pd.read_sql("SELECT * FROM Zip_Census", conn)

# %%
census_data.head()
# Out:
#          CityState         city state  Population  White Population  \
# 0      HOUSTON, TX      HOUSTON    TX     3061887           1775897
# 1      CHICAGO, IL      CHICAGO    IL     2702091           1318869
# 2     BROOKLYN, NY     BROOKLYN    NY     2595259           1126111
# 3  LOS ANGELES, CA  LOS ANGELES    CA     2426413           1068202
# 4        MIAMI, FL        MIAMI    FL     1820704           1361009
#
#    Black Population  Native American Population  Asian Population  \
# 0            684416                       11586            230549
# 1            843633                        7554            161478
# 2            870465                        8744            297890
# 3            324842                       15949            273829
# 4            363514                        2250             33144
#
#    Hispanic Population  Education None     ...      \
# 0              1368287           54180     ...
# 1               785374           32800     ...
# 2               509243           48934     ...
# 3              1292382           62684     ...
# 4              1162711           27137     ...
#
#    Employment Female Computer Engineering  Median Age  Median Male Age  \
# 0                                   22637   33.439583        32.550000
# 1                                   18209   34.526786        33.798214
# 2                                   14845   35.175676        33.367568
# 3                                   12329   35.335484        34.535484
# 4                                    6969   38.740741        37.120370
#
#    Median Female Age  Household Income  Income Per Capita  Median Gross Rent  \
# 0          34.363542       56206.50000        32239.52083         956.708333
# 1          35.141071       57735.96429        38730.83929        1119.928571
# 2          36.578378       51469.18919        28309.67568        1261.783784
# 3          36.061290       47494.58333        30073.19355        1201.766667
# 4          40.262963       51232.90741        25949.35185        1260.833333
#
#    Median Home Value        lat         lng
# 0        178233.6842  29.775734  -95.414548
# 1        264739.2857  41.867838  -87.673440
# 2        605743.2432  40.652805  -73.956528
# 3        557115.0000  34.042209 -118.303468
# 4        243279.6296  25.760268  -80.298511
#
# [5 rows x 31 columns]

# %%
zip_data.head()
# Out:
#    Median Age  Median Male Age  Median Female Age  Population  \
# 0        37.6             36.5               39.0       17982
# 1        39.5             38.6               40.3       40260
# 2        39.9             37.7               41.4       52408
# 3        40.8             41.0               40.3        6331
# 4        40.2             36.9               42.2       28328
#
#    White Population  Black Population  Native American Population  \
# 0             16956               102                          14
# 1             23144               693                           8
# 2             36177              2057                          76
# 3              4399               151                           0
# 4             17791               950                           0
#
#    Asian Population  Hispanic Population  Education None      ...        \
# 0                 0                17942             456      ...
# 1                72                37681             955      ...
# 2               655                50437            1014      ...
# 3                 0                 6323             188      ...
# 4                26                27999             377      ...
#
#    Median Gross Rent  Median Home Value  Employment Male Computer Engineering  \
# 0                359             104500                                    60
# 1                395              90200                                   211
# 2                384             128400                                   362
# 3                280             108500                                     9
# 4                424             113200                                   126
#
#    Employment Female Computer Engineering  zipcode        lat        lng  \
# 0                                      21    00601  18.180555 -66.749961
# 1                                      85    00602  18.361945 -67.175597
# 2                                     150    00603  18.455183 -67.119887
# 3                                       0    00606  18.158345 -66.932911
# 4                                      45    00610  18.295366 -67.125135
#
#         city  state      CityState
# 0   ADJUNTAS     PR   ADJUNTAS, PR
# 1     AGUADA     PR     AGUADA, PR
# 2  AGUADILLA     PR  AGUADILLA, PR
# 3    MARICAO     PR    MARICAO, PR
# 4     ANASCO     PR     ANASCO, PR
#
# [5 rows x 32 columns]

# %%
# Merge the columns
combined_data = pd.merge(census_data, zip_data, on="CityState", how="inner")

# %%
# Combined Data
combined_data.head()
# Out:
#          CityState       city_x state_x  Population_x  White Population_x  \
# 0  SPRINGFIELD, MA  SPRINGFIELD      MA        144780               79365
# 1  SPRINGFIELD, MA  SPRINGFIELD      MA        144780               79365
# 2  SPRINGFIELD, MA  SPRINGFIELD      MA        144780               79365
# 3  SPRINGFIELD, MA  SPRINGFIELD      MA        144780               79365
# 4  SPRINGFIELD, MA  SPRINGFIELD      MA        144780               79365
#
#    Black Population_x  Native American Population_x  Asian Population_x  \
# 0               30997                           777                2991
# 1               30997                           777                2991
# 2               30997                           777                2991
# 3               30997                           777                2991
# 4               30997                           777                2991
#
#    Hispanic Population_x  Education None_x   ...     Employment Unemployed_y  \
# 0                  61579              2325   ...                         192
# 1                  61579              2325   ...                        1495
# 2                  61579              2325   ...                         827
# 3                  61579              2325   ...                         971
# 4                  61579              2325   ...                        1532
#
#    Median Gross Rent_y  Median Home Value_y  \
# 0                  793               103100
# 1                  799               131200
# 2                  710               130700
# 3                  652               154000
# 4                  890               148200
#
#    Employment Male Computer Engineering_y  \
# 0                                      21
# 1                                      87
# 2                                      32
# 3                                      65
# 4                                     134
#
#    Employment Female Computer Engineering_y  zipcode      lat_y      lng_y  \
# 0                                        17    01103  42.104106 -72.592027
# 1                                        25    01104  42.134009 -72.565378
# 2                                         0    01105  42.099958 -72.580765
# 3                                        13    01107  42.121060 -72.607068
# 4                                        62    01108  42.080692 -72.560791
#
#         city_y  state_y
# 0  SPRINGFIELD       MA
# 1  SPRINGFIELD       MA
# 2  SPRINGFIELD       MA
# 3  SPRINGFIELD       MA
# 4  SPRINGFIELD       MA
#
# [5 rows x 62 columns]
