# %% [markdown]
#  01-Stu_Wrapper_RecapSolved

# %%
#import dependencies
import requests
from pprint import pprint
import json
import citipy
import openweathermapy.core as owm

# %%
# import api_key
from weather_api import api_key

# %%
# Create settings parameters
settings = {"units": "imperial", "APPID": api_key}

# %%
# make the API call using owm's get_fourcast_hourly method
forecast = owm.get_forecast_hourly("Phoenix, US", **settings)

# %%
forecast
# Out:
# [{'clouds': {'all': 0},
#   'dt': 1519873200,
#   'dt_txt': '2018-03-01 03:00:00',
#   'main': {'grnd_level': 980.73,
#    'humidity': 68,
#    'pressure': 980.73,
#    'sea_level': 1035.64,
#    'temp': 45.01,
#    'temp_kf': -0.2,
#    'temp_max': 45.37,
#    'temp_min': 45.01},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 221.501, 'speed': 4.61}},
#  {'clouds': {'all': 0},
#   'dt': 1519884000,
#   'dt_txt': '2018-03-01 06:00:00',
#   'main': {'grnd_level': 982.09,
#    'humidity': 87,
#    'pressure': 982.09,
#    'sea_level': 1037.7,
#    'temp': 38.28,
#    'temp_kf': -0.15,
#    'temp_max': 38.55,
#    'temp_min': 38.28},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 223.001, 'speed': 2.71}},
#  {'clouds': {'all': 0},
#   'dt': 1519894800,
#   'dt_txt': '2018-03-01 09:00:00',
#   'main': {'grnd_level': 982.22,
#    'humidity': 82,
#    'pressure': 982.22,
#    'sea_level': 1038.2,
#    'temp': 35.47,
#    'temp_kf': -0.1,
#    'temp_max': 35.66,
#    'temp_min': 35.47},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 33.5007, 'speed': 3.38}},
#  {'clouds': {'all': 0},
#   'dt': 1519905600,
#   'dt_txt': '2018-03-01 12:00:00',
#   'main': {'grnd_level': 981.37,
#    'humidity': 77,
#    'pressure': 981.37,
#    'sea_level': 1037.59,
#    'temp': 34.38,
#    'temp_kf': -0.05,
#    'temp_max': 34.47,
#    'temp_min': 34.38},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 59.5004, 'speed': 4.16}},
#  {'clouds': {'all': 0},
#   'dt': 1519916400,
#   'dt_txt': '2018-03-01 15:00:00',
#   'main': {'grnd_level': 981.4,
#    'humidity': 73,
#    'pressure': 981.4,
#    'sea_level': 1037.49,
#    'temp': 35.62,
#    'temp_kf': 0,
#    'temp_max': 35.62,
#    'temp_min': 35.62},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 20, 'speed': 4.16}},
#  {'clouds': {'all': 0},
#   'dt': 1519927200,
#   'dt_txt': '2018-03-01 18:00:00',
#   'main': {'grnd_level': 981.29,
#    'humidity': 66,
#    'pressure': 981.29,
#    'sea_level': 1035.57,
#    'temp': 53.97,
#    'temp_kf': 0,
#    'temp_max': 53.97,
#    'temp_min': 53.97},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 51.0046, 'speed': 3.96}},
#  {'clouds': {'all': 0},
#   'dt': 1519938000,
#   'dt_txt': '2018-03-01 21:00:00',
#   'main': {'grnd_level': 979.3,
#    'humidity': 62,
#    'pressure': 979.3,
#    'sea_level': 1032.64,
#    'temp': 60.37,
#    'temp_kf': 0,
#    'temp_max': 60.37,
#    'temp_min': 60.37},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 145, 'speed': 3.94}},
#  {'clouds': {'all': 0},
#   'dt': 1519948800,
#   'dt_txt': '2018-03-02 00:00:00',
#   'main': {'grnd_level': 978.04,
#    'humidity': 45,
#    'pressure': 978.04,
#    'sea_level': 1031.33,
#    'temp': 61.37,
#    'temp_kf': 0,
#    'temp_max': 61.37,
#    'temp_min': 61.37},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 165.501, 'speed': 3.94}},
#  {'clouds': {'all': 0},
#   'dt': 1519959600,
#   'dt_txt': '2018-03-02 03:00:00',
#   'main': {'grnd_level': 977.95,
#    'humidity': 60,
#    'pressure': 977.95,
#    'sea_level': 1032.13,
#    'temp': 47.04,
#    'temp_kf': 0,
#    'temp_max': 47.04,
#    'temp_min': 47.04},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 332.502, 'speed': 2.53}},
#  {'clouds': {'all': 0},
#   'dt': 1519970400,
#   'dt_txt': '2018-03-02 06:00:00',
#   'main': {'grnd_level': 978.03,
#    'humidity': 69,
#    'pressure': 978.03,
#    'sea_level': 1032.88,
#    'temp': 40.53,
#    'temp_kf': 0,
#    'temp_max': 40.53,
#    'temp_min': 40.53},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 0.525177, 'speed': 4.16}},
#  {'clouds': {'all': 0},
#   'dt': 1519981200,
#   'dt_txt': '2018-03-02 09:00:00',
#   'main': {'grnd_level': 977.36,
#    'humidity': 64,
#    'pressure': 977.36,
#    'sea_level': 1032.52,
#    'temp': 38.87,
#    'temp_kf': 0,
#    'temp_max': 38.87,
#    'temp_min': 38.87},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 34.5014, 'speed': 5.73}},
#  {'clouds': {'all': 0},
#   'dt': 1519992000,
#   'dt_txt': '2018-03-02 12:00:00',
#   'main': {'grnd_level': 976.73,
#    'humidity': 64,
#    'pressure': 976.73,
#    'sea_level': 1032,
#    'temp': 37.27,
#    'temp_kf': 0,
#    'temp_max': 37.27,
#    'temp_min': 37.27},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 48.001, 'speed': 5.28}},
#  {'clouds': {'all': 0},
#   'dt': 1520002800,
#   'dt_txt': '2018-03-02 15:00:00',
#   'main': {'grnd_level': 977.42,
#    'humidity': 58,
#    'pressure': 977.42,
#    'sea_level': 1032.6,
#    'temp': 39.24,
#    'temp_kf': 0,
#    'temp_max': 39.24,
#    'temp_min': 39.24},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 45.5016, 'speed': 4.72}},
#  {'clouds': {'all': 0},
#   'dt': 1520013600,
#   'dt_txt': '2018-03-02 18:00:00',
#   'main': {'grnd_level': 977.9,
#    'humidity': 59,
#    'pressure': 977.9,
#    'sea_level': 1031.35,
#    'temp': 60.37,
#    'temp_kf': 0,
#    'temp_max': 60.37,
#    'temp_min': 60.37},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 71.0001, 'speed': 3.71}},
#  {'clouds': {'all': 0},
#   'dt': 1520024400,
#   'dt_txt': '2018-03-02 21:00:00',
#   'main': {'grnd_level': 975.88,
#    'humidity': 52,
#    'pressure': 975.88,
#    'sea_level': 1028.7,
#    'temp': 66.46,
#    'temp_kf': 0,
#    'temp_max': 66.46,
#    'temp_min': 66.46},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 153.505, 'speed': 4.07}},
#  {'clouds': {'all': 0},
#   'dt': 1520035200,
#   'dt_txt': '2018-03-03 00:00:00',
#   'main': {'grnd_level': 974.56,
#    'humidity': 39,
#    'pressure': 974.56,
#    'sea_level': 1027.32,
#    'temp': 66.79,
#    'temp_kf': 0,
#    'temp_max': 66.79,
#    'temp_min': 66.79},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 191, 'speed': 3.62}},
#  {'clouds': {'all': 0},
#   'dt': 1520046000,
#   'dt_txt': '2018-03-03 03:00:00',
#   'main': {'grnd_level': 974.64,
#    'humidity': 52,
#    'pressure': 974.64,
#    'sea_level': 1028.35,
#    'temp': 50.85,
#    'temp_kf': 0,
#    'temp_max': 50.85,
#    'temp_min': 50.85},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 255.503, 'speed': 3.62}},
#  {'clouds': {'all': 0},
#   'dt': 1520056800,
#   'dt_txt': '2018-03-03 06:00:00',
#   'main': {'grnd_level': 975.1,
#    'humidity': 65,
#    'pressure': 975.1,
#    'sea_level': 1029.54,
#    'temp': 43.32,
#    'temp_kf': 0,
#    'temp_max': 43.32,
#    'temp_min': 43.32},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 296.502, 'speed': 3.38}},
#  {'clouds': {'all': 0},
#   'dt': 1520067600,
#   'dt_txt': '2018-03-03 09:00:00',
#   'main': {'grnd_level': 975.12,
#    'humidity': 69,
#    'pressure': 975.12,
#    'sea_level': 1029.76,
#    'temp': 40.05,
#    'temp_kf': 0,
#    'temp_max': 40.05,
#    'temp_min': 40.05},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 49.5069, 'speed': 1.77}},
#  {'clouds': {'all': 0},
#   'dt': 1520078400,
#   'dt_txt': '2018-03-03 12:00:00',
#   'main': {'grnd_level': 975.08,
#    'humidity': 72,
#    'pressure': 975.08,
#    'sea_level': 1029.81,
#    'temp': 37.41,
#    'temp_kf': 0,
#    'temp_max': 37.41,
#    'temp_min': 37.41},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 148.506, 'speed': 2.48}},
#  {'clouds': {'all': 0},
#   'dt': 1520089200,
#   'dt_txt': '2018-03-03 15:00:00',
#   'main': {'grnd_level': 976.18,
#    'humidity': 76,
#    'pressure': 976.18,
#    'sea_level': 1030.85,
#    'temp': 38.89,
#    'temp_kf': 0,
#    'temp_max': 38.89,
#    'temp_min': 38.89},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 141.508, 'speed': 2.57}},
#  {'clouds': {'all': 0},
#   'dt': 1520100000,
#   'dt_txt': '2018-03-03 18:00:00',
#   'main': {'grnd_level': 977.01,
#    'humidity': 60,
#    'pressure': 977.01,
#    'sea_level': 1030.17,
#    'temp': 60.04,
#    'temp_kf': 0,
#    'temp_max': 60.04,
#    'temp_min': 60.04},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 103.505, 'speed': 4.32}},
#  {'clouds': {'all': 0},
#   'dt': 1520110800,
#   'dt_txt': '2018-03-03 21:00:00',
#   'main': {'grnd_level': 975.29,
#    'humidity': 53,
#    'pressure': 975.29,
#    'sea_level': 1028.1,
#    'temp': 66.6,
#    'temp_kf': 0,
#    'temp_max': 66.6,
#    'temp_min': 66.6},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 179.506, 'speed': 4.38}},
#  {'clouds': {'all': 0},
#   'dt': 1520121600,
#   'dt_txt': '2018-03-04 00:00:00',
#   'main': {'grnd_level': 974.31,
#    'humidity': 40,
#    'pressure': 974.31,
#    'sea_level': 1027.14,
#    'temp': 65.68,
#    'temp_kf': 0,
#    'temp_max': 65.68,
#    'temp_min': 65.68},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 223.5, 'speed': 7.23}},
#  {'clouds': {'all': 24},
#   'dt': 1520132400,
#   'dt_txt': '2018-03-04 03:00:00',
#   'main': {'grnd_level': 975.02,
#    'humidity': 61,
#    'pressure': 975.02,
#    'sea_level': 1028.68,
#    'temp': 53.3,
#    'temp_kf': 0,
#    'temp_max': 53.3,
#    'temp_min': 53.3},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 234.003, 'speed': 5.53}},
#  {'clouds': {'all': 36},
#   'dt': 1520143200,
#   'dt_txt': '2018-03-04 06:00:00',
#   'main': {'grnd_level': 975.51,
#    'humidity': 82,
#    'pressure': 975.51,
#    'sea_level': 1029.68,
#    'temp': 45.75,
#    'temp_kf': 0,
#    'temp_max': 45.75,
#    'temp_min': 45.75},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 211.01, 'speed': 2.59}},
#  {'clouds': {'all': 100},
#   'dt': 1520154000,
#   'dt_txt': '2018-03-04 09:00:00',
#   'main': {'grnd_level': 975.59,
#    'humidity': 83,
#    'pressure': 975.59,
#    'sea_level': 1030.13,
#    'temp': 44.74,
#    'temp_kf': 0,
#    'temp_max': 44.74,
#    'temp_min': 44.74},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 130.503, 'speed': 1.74}},
#  {'clouds': {'all': 92},
#   'dt': 1520164800,
#   'dt_txt': '2018-03-04 12:00:00',
#   'main': {'grnd_level': 975.86,
#    'humidity': 74,
#    'pressure': 975.86,
#    'sea_level': 1030.67,
#    'temp': 47.29,
#    'temp_kf': 0,
#    'temp_max': 47.29,
#    'temp_min': 47.29},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 265.503, 'speed': 5.55}},
#  {'clouds': {'all': 92},
#   'dt': 1520175600,
#   'dt_txt': '2018-03-04 15:00:00',
#   'main': {'grnd_level': 977.76,
#    'humidity': 58,
#    'pressure': 977.76,
#    'sea_level': 1032.8,
#    'temp': 48.01,
#    'temp_kf': 0,
#    'temp_max': 48.01,
#    'temp_min': 48.01},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04d',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 245.001, 'speed': 6.04}},
#  {'clouds': {'all': 0},
#   'dt': 1520186400,
#   'dt_txt': '2018-03-04 18:00:00',
#   'main': {'grnd_level': 980.1,
#    'humidity': 63,
#    'pressure': 980.1,
#    'sea_level': 1034.22,
#    'temp': 52.43,
#    'temp_kf': 0,
#    'temp_max': 52.43,
#    'temp_min': 52.43},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 260.501, 'speed': 6.64}},
#  {'clouds': {'all': 0},
#   'dt': 1520197200,
#   'dt_txt': '2018-03-04 21:00:00',
#   'main': {'grnd_level': 979.76,
#    'humidity': 54,
#    'pressure': 979.76,
#    'sea_level': 1033.45,
#    'temp': 57.47,
#    'temp_kf': 0,
#    'temp_max': 57.47,
#    'temp_min': 57.47},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 272.503, 'speed': 5.61}},
#  {'clouds': {'all': 0},
#   'dt': 1520208000,
#   'dt_txt': '2018-03-05 00:00:00',
#   'main': {'grnd_level': 979.54,
#    'humidity': 39,
#    'pressure': 979.54,
#    'sea_level': 1033.23,
#    'temp': 57.21,
#    'temp_kf': 0,
#    'temp_max': 57.21,
#    'temp_min': 57.21},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 274.504, 'speed': 6.11}},
#  {'clouds': {'all': 0},
#   'dt': 1520218800,
#   'dt_txt': '2018-03-05 03:00:00',
#   'main': {'grnd_level': 980.47,
#    'humidity': 48,
#    'pressure': 980.47,
#    'sea_level': 1035.1,
#    'temp': 45.8,
#    'temp_kf': 0,
#    'temp_max': 45.8,
#    'temp_min': 45.8},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 235.5, 'speed': 3.89}},
#  {'clouds': {'all': 0},
#   'dt': 1520229600,
#   'dt_txt': '2018-03-05 06:00:00',
#   'main': {'grnd_level': 981.14,
#    'humidity': 61,
#    'pressure': 981.14,
#    'sea_level': 1036.47,
#    'temp': 38.85,
#    'temp_kf': 0,
#    'temp_max': 38.85,
#    'temp_min': 38.85},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 263.501, 'speed': 3.06}},
#  {'clouds': {'all': 0},
#   'dt': 1520240400,
#   'dt_txt': '2018-03-05 09:00:00',
#   'main': {'grnd_level': 981,
#    'humidity': 63,
#    'pressure': 981,
#    'sea_level': 1036.72,
#    'temp': 36.18,
#    'temp_kf': 0,
#    'temp_max': 36.18,
#    'temp_min': 36.18},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 21.5005, 'speed': 3.49}},
#  {'clouds': {'all': 0},
#   'dt': 1520251200,
#   'dt_txt': '2018-03-05 12:00:00',
#   'main': {'grnd_level': 980.01,
#    'humidity': 61,
#    'pressure': 980.01,
#    'sea_level': 1036.04,
#    'temp': 35.07,
#    'temp_kf': 0,
#    'temp_max': 35.07,
#    'temp_min': 35.07},
#   'rain': {},
#   'sys': {'pod': 'n'},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 26.0028, 'speed': 4.63}},
#  {'clouds': {'all': 8},
#   'dt': 1520262000,
#   'dt_txt': '2018-03-05 15:00:00',
#   'main': {'grnd_level': 980.65,
#    'humidity': 46,
#    'pressure': 980.65,
#    'sea_level': 1036.48,
#    'temp': 38.26,
#    'temp_kf': 0,
#    'temp_max': 38.26,
#    'temp_min': 38.26},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'weather': [{'description': 'clear sky',
#     'icon': '02d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 31.0034, 'speed': 6.96}},
#  {'clouds': {'all': 56},
#   'dt': 1520272800,
#   'dt_txt': '2018-03-05 18:00:00',
#   'main': {'grnd_level': 981.32,
#    'humidity': 48,
#    'pressure': 981.32,
#    'sea_level': 1035.38,
#    'temp': 55.37,
#    'temp_kf': 0,
#    'temp_max': 55.37,
#    'temp_min': 55.37},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 32.5017, 'speed': 5.17}},
#  {'clouds': {'all': 64},
#   'dt': 1520283600,
#   'dt_txt': '2018-03-05 21:00:00',
#   'main': {'grnd_level': 979.36,
#    'humidity': 42,
#    'pressure': 979.36,
#    'sea_level': 1032.83,
#    'temp': 60.73,
#    'temp_kf': 0,
#    'temp_max': 60.73,
#    'temp_min': 60.73},
#   'rain': {},
#   'sys': {'pod': 'd'},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 22.5003, 'speed': 4.16}}]

# %%
print( f"{type(forecast)} {len(forecast)}")
# Out:
# <class 'openweathermapy.core.DataBlock'> 39

# %%
forecast[0]
# Out:
# {'clouds': {'all': 0},
#  'dt': 1519873200,
#  'dt_txt': '2018-03-01 03:00:00',
#  'main': {'grnd_level': 980.73,
#   'humidity': 68,
#   'pressure': 980.73,
#   'sea_level': 1035.64,
#   'temp': 45.01,
#   'temp_kf': -0.2,
#   'temp_max': 45.37,
#   'temp_min': 45.01},
#  'rain': {},
#  'sys': {'pod': 'n'},
#  'weather': [{'description': 'clear sky',
#    'icon': '01n',
#    'id': 800,
#    'main': 'Clear'}],
#  'wind': {'deg': 221.501, 'speed': 4.61}}

# %%
forecast[0]("dt_txt", "main.temp")
# Out:
# ('2018-03-01 03:00:00', 45.01)

# %%
# extract the date in text format and the temperature from each record
# and save them in a list
summary = ["dt_txt", "main.temp"]
data = [hourly_forecast(*summary) for hourly_forecast in forecast]

# format the printing of each record
for hourly_forecast in data:
    print(f"{hourly_forecast[0]} | {hourly_forecast[1]} F")
# Out:
# 2018-03-01 03:00:00 | 45.01 F
# 2018-03-01 06:00:00 | 38.28 F
# 2018-03-01 09:00:00 | 35.47 F
# 2018-03-01 12:00:00 | 34.38 F
# 2018-03-01 15:00:00 | 35.62 F
# 2018-03-01 18:00:00 | 53.97 F
# 2018-03-01 21:00:00 | 60.37 F
# 2018-03-02 00:00:00 | 61.37 F
# 2018-03-02 03:00:00 | 47.04 F
# 2018-03-02 06:00:00 | 40.53 F
# 2018-03-02 09:00:00 | 38.87 F
# 2018-03-02 12:00:00 | 37.27 F
# 2018-03-02 15:00:00 | 39.24 F
# 2018-03-02 18:00:00 | 60.37 F
# 2018-03-02 21:00:00 | 66.46 F
# 2018-03-03 00:00:00 | 66.79 F
# 2018-03-03 03:00:00 | 50.85 F
# 2018-03-03 06:00:00 | 43.32 F
# 2018-03-03 09:00:00 | 40.05 F
# 2018-03-03 12:00:00 | 37.41 F
# 2018-03-03 15:00:00 | 38.89 F
# 2018-03-03 18:00:00 | 60.04 F
# 2018-03-03 21:00:00 | 66.6 F
# 2018-03-04 00:00:00 | 65.68 F
# 2018-03-04 03:00:00 | 53.3 F
# 2018-03-04 06:00:00 | 45.75 F
# 2018-03-04 09:00:00 | 44.74 F
# 2018-03-04 12:00:00 | 47.29 F
# 2018-03-04 15:00:00 | 48.01 F
# 2018-03-04 18:00:00 | 52.43 F
# 2018-03-04 21:00:00 | 57.47 F
# 2018-03-05 00:00:00 | 57.21 F
# 2018-03-05 03:00:00 | 45.8 F
# 2018-03-05 06:00:00 | 38.85 F
# 2018-03-05 09:00:00 | 36.18 F
# 2018-03-05 12:00:00 | 35.07 F
# 2018-03-05 15:00:00 | 38.26 F
# 2018-03-05 18:00:00 | 55.37 F
# 2018-03-05 21:00:00 | 60.73 F

# %%
# BONUS 1
# use owm's select method to select the desired data from
# each record in the response

selection = ["dt_txt", "main.temp"]
data = forecast.select(selection)

# print formatted results
for hourly_forecast in data:
    print(f"{hourly_forecast[0]} | {hourly_forecast[1]} F")
# Out:
# 2018-03-01 03:00:00 | 45.01 F
# 2018-03-01 06:00:00 | 38.28 F
# 2018-03-01 09:00:00 | 35.47 F
# 2018-03-01 12:00:00 | 34.38 F
# 2018-03-01 15:00:00 | 35.62 F
# 2018-03-01 18:00:00 | 53.97 F
# 2018-03-01 21:00:00 | 60.37 F
# 2018-03-02 00:00:00 | 61.37 F
# 2018-03-02 03:00:00 | 47.04 F
# 2018-03-02 06:00:00 | 40.53 F
# 2018-03-02 09:00:00 | 38.87 F
# 2018-03-02 12:00:00 | 37.27 F
# 2018-03-02 15:00:00 | 39.24 F
# 2018-03-02 18:00:00 | 60.37 F
# 2018-03-02 21:00:00 | 66.46 F
# 2018-03-03 00:00:00 | 66.79 F
# 2018-03-03 03:00:00 | 50.85 F
# 2018-03-03 06:00:00 | 43.32 F
# 2018-03-03 09:00:00 | 40.05 F
# 2018-03-03 12:00:00 | 37.41 F
# 2018-03-03 15:00:00 | 38.89 F
# 2018-03-03 18:00:00 | 60.04 F
# 2018-03-03 21:00:00 | 66.6 F
# 2018-03-04 00:00:00 | 65.68 F
# 2018-03-04 03:00:00 | 53.3 F
# 2018-03-04 06:00:00 | 45.75 F
# 2018-03-04 09:00:00 | 44.74 F
# 2018-03-04 12:00:00 | 47.29 F
# 2018-03-04 15:00:00 | 48.01 F
# 2018-03-04 18:00:00 | 52.43 F
# 2018-03-04 21:00:00 | 57.47 F
# 2018-03-05 00:00:00 | 57.21 F
# 2018-03-05 03:00:00 | 45.8 F
# 2018-03-05 06:00:00 | 38.85 F
# 2018-03-05 09:00:00 | 36.18 F
# 2018-03-05 12:00:00 | 35.07 F
# 2018-03-05 15:00:00 | 38.26 F
# 2018-03-05 18:00:00 | 55.37 F
# 2018-03-05 21:00:00 | 60.73 F

# %%
# BONUS 2
import datetime
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter

temps = [t for dt, t in data]
times = [datetime.datetime.strptime(dt, "%Y-%m-%d %H:%M:%S") 
         for dt, t in data]

# Plot the temperatures over time
plt.plot(times, temps)
formatter = DateFormatter('%Y-%m-%d %H:%M:%S')
plt.gcf().axes[0].xaxis.set_major_formatter(formatter)
plt.gcf().autofmt_xdate()
plt.show();
