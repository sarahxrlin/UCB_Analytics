# %%
# Dependencies
import tweepy
import json
from config import consumer_key, consumer_secret, access_token, access_token_secret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Search Term
search_term = input("Which term would you like to search for? ")

# Search for all tweets
public_tweets = api.search(search_term)
public_tweets
# Out:
# Which term would you like to search for? canada immigration
# {'search_metadata': {'completed_in': 0.06,
#   'count': 15,
#   'max_id': 969008868046135298,
#   'max_id_str': '969008868046135298',
#   'next_results': '?max_id=968996307045109759&q=canada%20immigration&include_entities=1',
#   'query': 'canada+immigration',
#   'refresh_url': '?since_id=969008868046135298&q=canada%20immigration&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 01 00:38:12 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 831625957,
#       'id_str': '831625957',
#       'indices': [3, 17],
#       'name': 'Cdn Refugee Lawyers',
#       'screen_name': 'CARLadvocates'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 969008868046135298,
#    'id_str': '969008868046135298',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 16,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Mon Feb 26 16:25:46 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/968160168033816577',
#        'indices': [117, 140],
#        'url': 'https://t.co/6thR1X5o0x'}],
#      'user_mentions': []},
#     'favorite_count': 4,
#     'favorited': False,
#     'geo': None,
#     'id': 968160168033816577,
#     'id_str': '968160168033816577',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 16,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': 'Shameful and a violation of international standards: Immigration detainee Ebrahim Toure marks five years without fr… https://t.co/6thR1X5o0x',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Sep 18 18:29:18 +0000 2012',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': "The Canadian Association of Refugee Lawyers (CARL) advocates for refugee rights in Canada  | L'ACAADR défend les droits des réfugiés au Canada",
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'carl-acaadr.ca',
#          'expanded_url': 'http://www.carl-acaadr.ca/',
#          'indices': [0, 22],
#          'url': 'http://t.co/PzAPAPRool'}]}},
#      'favourites_count': 310,
#      'follow_request_sent': False,
#      'followers_count': 5387,
#      'following': False,
#      'friends_count': 2422,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 831625957,
#      'id_str': '831625957',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 142,
#      'location': 'RTs not endorsements | Canada',
#      'name': 'Cdn Refugee Lawyers',
#      'notifications': False,
#      'profile_background_color': '01030A',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000001402357/a3c8bd8fa664462d2d5d32613c309f8b.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000001402357/a3c8bd8fa664462d2d5d32613c309f8b.jpeg',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/831625957/1398261177',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/3055697346/5171f74ac69aa49ff3582d4fd58105cc_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3055697346/5171f74ac69aa49ff3582d4fd58105cc_normal.jpeg',
#      'profile_link_color': '730716',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'A0C5C7',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'CARLadvocates',
#      'statuses_count': 5878,
#      'time_zone': 'Eastern Time (US & Canada)',
#      'translator_type': 'none',
#      'url': 'http://t.co/PzAPAPRool',
#      'utc_offset': -18000,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @CARLadvocates: Shameful and a violation of international standards: Immigration detainee Ebrahim Toure marks five years without freedom…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Nov 02 23:30:46 +0000 2013',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Toronto immigration and refugee lawyer since 1987.  Posts are not legal advice.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'douglaslehrer.ca',
#         'expanded_url': 'http://www.douglaslehrer.ca',
#         'indices': [0, 23],
#         'url': 'https://t.co/eX4tbSDycG'}]}},
#     'favourites_count': 6,
#     'follow_request_sent': False,
#     'followers_count': 36,
#     'following': False,
#     'friends_count': 21,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 2171119550,
#     'id_str': '2171119550',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': 'Toronto',
#     'name': 'Douglas Lehrer',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2171119550/1422235270',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/559521387421773824/FCRj1xZ1_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/559521387421773824/FCRj1xZ1_normal.jpeg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'douglehrer',
#     'statuses_count': 62,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/eX4tbSDycG',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 01 00:34:46 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'bbc.com/news/world-us-…',
#       'expanded_url': 'http://www.bbc.com/news/world-us-canada-43230268',
#       'indices': [71, 94],
#       'url': 'https://t.co/zVTjbyXhkl'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 969008006196334593,
#    'id_str': '969008006196334593',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'Oakland Mayor Libby Schaaf defends immigration raid tip-off - BBC News https://t.co/zVTjbyXhkl',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Dec 04 09:37:15 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'proud liberal notmypresident.  #theresistance #Trumprussia #resistance #russiagate #fbr #metoo',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 180922,
#     'follow_request_sent': False,
#     'followers_count': 6958,
#     'following': False,
#     'friends_count': 7651,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 805345210557493248,
#     'id_str': '805345210557493248',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 39,
#     'location': '',
#     'name': 'Bethsinni',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805345210557493248/1511750385',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/965871844665503744/gP7fExz1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/965871844665503744/gP7fExz1_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'bethsinniresist',
#     'statuses_count': 259250,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -18000,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 01 00:32:37 +0000 2018',
#    'entities': {'hashtags': [{'indices': [99, 107], 'text': 'cdnpoli'}],
#     'media': [{'display_url': 'pic.twitter.com/DweI2EVRjA',
#       'expanded_url': 'https://twitter.com/sjgarvey/status/969007465755914240/photo/1',
#       'id': 969007442066522112,
#       'id_str': '969007442066522112',
#       'indices': [108, 131],
#       'media_url': 'http://pbs.twimg.com/media/DXKbInEVwAAMq7w.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DXKbInEVwAAMq7w.jpg',
#       'sizes': {'large': {'h': 1083, 'resize': 'fit', 'w': 760},
#        'medium': {'h': 1083, 'resize': 'fit', 'w': 760},
#        'small': {'h': 680, 'resize': 'fit', 'w': 477},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/DweI2EVRjA'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/DweI2EVRjA',
#       'expanded_url': 'https://twitter.com/sjgarvey/status/969007465755914240/photo/1',
#       'id': 969007442066522112,
#       'id_str': '969007442066522112',
#       'indices': [108, 131],
#       'media_url': 'http://pbs.twimg.com/media/DXKbInEVwAAMq7w.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DXKbInEVwAAMq7w.jpg',
#       'sizes': {'large': {'h': 1083, 'resize': 'fit', 'w': 760},
#        'medium': {'h': 1083, 'resize': 'fit', 'w': 760},
#        'small': {'h': 680, 'resize': 'fit', 'w': 477},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/DweI2EVRjA'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 969007465755914240,
#    'id_str': '969007465755914240',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'This will blow your mind: mass immigration into Canada and the nonsensical approach behind it..... #cdnpoli https://t.co/DweI2EVRjA',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Apr 14 19:33:53 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Founding Member of the National Citizens Alliance (NCA); no PC; zero tolerance for radical ideologies; Canadian people FIRST',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'nationaladvancement.ca',
#         'expanded_url': 'https://www.nationaladvancement.ca',
#         'indices': [0, 23],
#         'url': 'https://t.co/OAPiXpNkux'}]}},
#     'favourites_count': 3606,
#     'follow_request_sent': False,
#     'followers_count': 520,
#     'following': False,
#     'friends_count': 168,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 282211632,
#     'id_str': '282211632',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 25,
#     'location': 'Canada',
#     'name': 'Stephen Garvey 🇨🇦',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000162259886/T1B_m5_E.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000162259886/T1B_m5_E.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/282211632/1519602496',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/825178997357047808/tpvGKwKN_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/825178997357047808/tpvGKwKN_normal.jpg',
#     'profile_link_color': '710039',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'sjgarvey',
#     'statuses_count': 9764,
#     'time_zone': 'Mountain Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/OAPiXpNkux',
#     'utc_offset': -25200,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 01 00:32:31 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/969007437599707136',
#       'indices': [117, 140],
#       'url': 'https://t.co/HcVuIVaf3q'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 969007437599707136,
#    'id_str': '969007437599707136',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'Powerful video. A rural community realizes the emotional and economic consequences of the Trump immigration crackdo… https://t.co/HcVuIVaf3q',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Jul 12 22:32:08 +0000 2009',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 559,
#     'follow_request_sent': False,
#     'followers_count': 8,
#     'following': False,
#     'friends_count': 158,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 56210742,
#     'id_str': '56210742',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': 'Prior Lake, MN',
#     'name': 'Adnan Ahmed',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/56210742/1410817215',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1805110907/image_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1805110907/image_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'adnanahmed9271',
#     'statuses_count': 4,
#     'time_zone': 'Quito',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -18000,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 01 00:29:42 +0000 2018',
#    'entities': {'hashtags': [{'indices': [100, 112], 'text': 'immigration'}],
#     'symbols': [],
#     'urls': [{'display_url': 'goo.gl/fb/Fw2Gqg',
#       'expanded_url': 'https://goo.gl/fb/Fw2Gqg',
#       'indices': [76, 99],
#       'url': 'https://t.co/dA39EVRKxB'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 969006732230840320,
#    'id_str': '969006732230840320',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://www.google.com/" rel="nofollow">Google</a>',
#    'text': 'Doug Saunders’ “Maximum Canada” = Minimum White Canadians: Doug Saunders’s… https://t.co/dA39EVRKxB #immigration',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Oct 28 12:37:46 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Monotoring immigration.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'immigration.startmix.nl',
#         'expanded_url': 'http://immigration.startmix.nl/',
#         'indices': [0, 23],
#         'url': 'https://t.co/btwOqpmrMn'}]}},
#     'favourites_count': 2,
#     'follow_request_sent': False,
#     'followers_count': 738,
#     'following': False,
#     'friends_count': 2366,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 924253859798835201,
#     'id_str': '924253859798835201',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'nl',
#     'listed_count': 2,
#     'location': '',
#     'name': 'Immigration Monitor',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/924253859798835201/1509196844',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/924265462514507776/NhzarXlq_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/924265462514507776/NhzarXlq_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'MassMigrations',
#     'statuses_count': 1644,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/btwOqpmrMn',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 01 00:19:29 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 1080324554,
#       'id_str': '1080324554',
#       'indices': [3, 19],
#       'name': 'Air Canada México',
#       'screen_name': 'AirCanadaMexico'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 969004158446583808,
#    'id_str': '969004158446583808',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 3,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Feb 28 14:12:21 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/968851370781564928',
#        'indices': [117, 140],
#        'url': 'https://t.co/iofuucXCu3'}],
#      'user_mentions': []},
#     'favorite_count': 4,
#     'favorited': False,
#     'geo': None,
#     'id': 968851370781564928,
#     'id_str': '968851370781564928',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 3,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'Los ciudadanos mexicanos no necesitan visa para ir a Canadá, No obstante, deberán contar con una Autorización elect… https://t.co/iofuucXCu3',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Jan 11 17:09:41 +0000 2013',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Cuenta oficial de Air Canada México. Call center D.F. 91.38.02.80 / LADA sin costo 01.800.719.28.27.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'aircanada.com/mx/es/home.html',
#          'expanded_url': 'http://www.aircanada.com/mx/es/home.html',
#          'indices': [0, 22],
#          'url': 'http://t.co/IEbl3oNpnJ'}]}},
#      'favourites_count': 1529,
#      'follow_request_sent': False,
#      'followers_count': 1584,
#      'following': False,
#      'friends_count': 330,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 1080324554,
#      'id_str': '1080324554',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'es',
#      'listed_count': 22,
#      'location': 'México, D.F.',
#      'name': 'Air Canada México',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/761267552/148bdbfce675e84cdaff30abe1833f56.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/761267552/148bdbfce675e84cdaff30abe1833f56.jpeg',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1080324554/1504710868',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/830064377474609153/V7pTesmE_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/830064377474609153/V7pTesmE_normal.jpg',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'AirCanadaMexico',
#      'statuses_count': 6419,
#      'time_zone': 'Central Time (US & Canada)',
#      'translator_type': 'none',
#      'url': 'http://t.co/IEbl3oNpnJ',
#      'utc_offset': -21600,
#      'verified': True}},
#    'source': '<a href="https://soccer-quest.now.sh" rel="nofollow">Soccer Quest</a>',
#    'text': 'RT @AirCanadaMexico: Los ciudadanos mexicanos no necesitan visa para ir a Canadá, No obstante, deberán contar con una Autorización electrón…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Feb 27 08:45:33 +0000 2018',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 0,
#     'follow_request_sent': False,
#     'followers_count': 1,
#     'following': False,
#     'friends_count': 0,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 968406737031229441,
#     'id_str': '968406737031229441',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': '',
#     'name': 'Guillermina Yanez',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/968406922993876993/5EoumMoM_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/968406922993876993/5EoumMoM_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'nayanez9',
#     'statuses_count': 97,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 01 00:19:20 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/969004120370683905',
#       'indices': [114, 137],
#       'url': 'https://t.co/OSB5j2YA2h'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 969004120370683905,
#    'id_str': '969004120370683905',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "Secure Express Entry to Canada without a Canadian job offer. Learn how it's possible with Calver and Associates:… https://t.co/OSB5j2YA2h",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Dec 01 18:26:37 +0000 2017',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Canadian Immigration Services firm located in Oshawa and Cobourg, Ontario.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'calverimmigrationservices.com',
#         'expanded_url': 'http://www.calverimmigrationservices.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/hpaciB9LQO'}]}},
#     'favourites_count': 5,
#     'follow_request_sent': False,
#     'followers_count': 9,
#     'following': False,
#     'friends_count': 72,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 936662835224104960,
#     'id_str': '936662835224104960',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': 'Oshawa, Ontario',
#     'name': 'Calver & Associates',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/936662835224104960/1512153668',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/936666428983218176/dGFYVbQI_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/936666428983218176/dGFYVbQI_normal.jpg',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'Calverandassoc',
#     'statuses_count': 7,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/hpaciB9LQO',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 01 00:07:46 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 3652858692,
#       'id_str': '3652858692',
#       'indices': [3, 14],
#       'name': 'Rebecca Chahine',
#       'screen_name': 'MrsChahine'},
#      {'id': 161395767,
#       'id_str': '161395767',
#       'indices': [117, 127],
#       'name': 'Learning Partnership',
#       'screen_name': 'TLPCanada'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 969001209221672960,
#    'id_str': '969001209221672960',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 8,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Feb 27 21:46:57 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/968603386726748161',
#        'indices': [113, 136],
#        'url': 'https://t.co/4TU88FHG5Q'}],
#      'user_mentions': [{'id': 161395767,
#        'id_str': '161395767',
#        'indices': [101, 111],
#        'name': 'Learning Partnership',
#        'screen_name': 'TLPCanada'}]},
#     'favorite_count': 13,
#     'favorited': False,
#     'geo': None,
#     'id': 968603386726748161,
#     'id_str': '968603386726748161',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 8,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#     'text': 'Ss share their immigration stories and being welcomed to Canada with Canada’s Outstanding Principals @TLPCanada… https://t.co/4TU88FHG5Q',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Sep 22 22:02:00 +0000 2015',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'Grade 5 Teacher for TDSB, mother of 3, passionate about environmental teaching and 21st century learning',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 2123,
#      'follow_request_sent': False,
#      'followers_count': 384,
#      'following': False,
#      'friends_count': 568,
#      'geo_enabled': True,
#      'has_extended_profile': True,
#      'id': 3652858692,
#      'id_str': '3652858692',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 6,
#      'location': 'Toronto, Ontario',
#      'name': 'Rebecca Chahine',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3652858692/1517064693',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/948735015554252800/rhyZIDEq_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/948735015554252800/rhyZIDEq_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'MrsChahine',
#      'statuses_count': 1169,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @MrsChahine: Ss share their immigration stories and being welcomed to Canada with Canada’s Outstanding Principals @TLPCanada @ThelmaSamb…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Oct 24 00:53:53 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': True,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 49,
#     'follow_request_sent': False,
#     'followers_count': 0,
#     'following': False,
#     'friends_count': 47,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 922627169569849346,
#     'id_str': '922627169569849346',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': '',
#     'name': 'Hania Asif',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'HaniaAsif2',
#     'statuses_count': 8,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 01 00:07:45 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/969001206583648256',
#       'indices': [117, 140],
#       'url': 'https://t.co/kZwOV5vzsv'}],
#     'user_mentions': [{'id': 35785401,
#       'id_str': '35785401',
#       'indices': [0, 12],
#       'name': 'Univision Noticias',
#       'screen_name': 'UniNoticias'},
#      {'id': 62805448,
#       'id_str': '62805448',
#       'indices': [14, 30],
#       'name': 'Immigration Canada',
#       'screen_name': 'ImmigrationCana'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 969001206583648256,
#    'id_str': '969001206583648256',
#    'in_reply_to_screen_name': 'chechimartinez',
#    'in_reply_to_status_id': 968974495343144960,
#    'in_reply_to_status_id_str': '968974495343144960',
#    'in_reply_to_user_id': 139086342,
#    'in_reply_to_user_id_str': '139086342',
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': '@UniNoticias  @ImmigrationCana has guidelines on how to apply for any situation. Refugee claims, work visas, studen… https://t.co/kZwOV5vzsv',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat May 01 14:09:39 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': True,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 190,
#     'follow_request_sent': False,
#     'followers_count': 53,
#     'following': False,
#     'friends_count': 418,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 139086342,
#     'id_str': '139086342',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': '',
#     'name': 'Chechimartinez',
#     'notifications': False,
#     'profile_background_color': 'ACDED6',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '038543',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'F6F6F6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'chechimartinez',
#     'statuses_count': 4475,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Feb 28 23:56:32 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'bbc.co.uk/news/world-us-…',
#       'expanded_url': 'http://www.bbc.co.uk/news/world-us-canada-43230268',
#       'indices': [85, 108],
#       'url': 'https://t.co/SastRDlEY5'}],
#     'user_mentions': [{'id': 2334295476,
#       'id_str': '2334295476',
#       'indices': [3, 14],
#       'name': 'BFD USN',
#       'screen_name': 'BFD1982USN'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 968998382378389504,
#    'id_str': '968998382378389504',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Feb 28 23:39:40 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'bbc.co.uk/news/world-us-…',
#        'expanded_url': 'http://www.bbc.co.uk/news/world-us-canada-43230268',
#        'indices': [69, 92],
#        'url': 'https://t.co/SastRDlEY5'}],
#      'user_mentions': []},
#     'favorite_count': 0,
#     'favorited': False,
#     'geo': None,
#     'id': 968994139487563776,
#     'id_str': '968994139487563776',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'Criminal Oakland Mayor Libby Schaaf defends immigration raid tip-off https://t.co/SastRDlEY5',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sun Feb 09 00:47:43 +0000 2014',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '#Deplorable #AmericanInfidel #DAV #USN #Shellback 🔴follow the DNC💰 #MAGA 💯45 #1A #2A 🇺🇸🇮🇱✝️ #BlueLivesMatter #BuildTheWall #NRAmember Andy & Steve R🤡',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 2154,
#      'follow_request_sent': False,
#      'followers_count': 12683,
#      'following': False,
#      'friends_count': 12452,
#      'geo_enabled': False,
#      'has_extended_profile': True,
#      'id': 2334295476,
#      'id_str': '2334295476',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 13,
#      'location': 'The Moon',
#      'name': 'BFD USN',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2334295476/1519515490',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/955109281644404736/tzse5FX-_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/955109281644404736/tzse5FX-_normal.jpg',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'BFD1982USN',
#      'statuses_count': 28157,
#      'time_zone': 'Eastern Time (US & Canada)',
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': -18000,
#      'verified': False}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'RT @BFD1982USN: Criminal Oakland Mayor Libby Schaaf defends immigration raid tip-off https://t.co/SastRDlEY5',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Nov 29 17:22:15 +0000 2012',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Country living, dogs, cats, birds, all animals. Thankful to be American, Pro-America #PeopleNeedTheLord #MAGA',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 41984,
#     'follow_request_sent': False,
#     'followers_count': 1816,
#     'following': False,
#     'friends_count': 2248,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 978780686,
#     'id_str': '978780686',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 32,
#     'location': 'United States',
#     'name': 'LaurieUSA❤',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/978780686/1444504037',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/652925799398547456/b_dYddNp_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/652925799398547456/b_dYddNp_normal.jpg',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'LaurieC710',
#     'statuses_count': 21951,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -28800,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Feb 28 23:52:45 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 91193025,
#       'id_str': '91193025',
#       'indices': [3, 16],
#       'name': 'IRCC',
#       'screen_name': 'CitImmCanada'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 968997433010253825,
#    'id_str': '968997433010253825',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 29,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Feb 21 18:07:03 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/966373717281558529',
#        'indices': [117, 140],
#        'url': 'https://t.co/Uoq6eadmFX'}],
#      'user_mentions': []},
#     'favorite_count': 44,
#     'favorited': False,
#     'geo': None,
#     'id': 966373717281558529,
#     'id_str': '966373717281558529',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 29,
#     'retweeted': False,
#     'scopes': {'followers': False},
#     'source': '<a href="https://ads-api.twitter.com" rel="nofollow">Twitter Ads Composer</a>',
#     'text': 'Keep top international talent in Atlantic Canada. Learn how the Atlantic Immigration Pilot program can benefit your… https://t.co/Uoq6eadmFX',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Nov 19 21:07:25 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Immigration, Refugees and Citizenship Canada (IRCC) – formerly Citizenship and Immigration Canada (CIC). (Terms: https://t.co/mctP8GaIhH) -Français:@CitImmCanFR',
#      'entities': {'description': {'urls': [{'display_url': 'j.mp/1nJith2',
#          'expanded_url': 'http://j.mp/1nJith2',
#          'indices': [113, 136],
#          'url': 'https://t.co/mctP8GaIhH'}]},
#       'url': {'urls': [{'expanded_url': None,
#          'indices': [0, 20],
#          'url': 'http://www.cic.gc.ca'}]}},
#      'favourites_count': 146,
#      'follow_request_sent': False,
#      'followers_count': 149835,
#      'following': False,
#      'friends_count': 290,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 91193025,
#      'id_str': '91193025',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 1031,
#      'location': 'Canada',
#      'name': 'IRCC',
#      'notifications': False,
#      'profile_background_color': 'FFFFFF',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/886550258/a7ee2679d7b09b8fdd174d9424972ac2.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/886550258/a7ee2679d7b09b8fdd174d9424972ac2.jpeg',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/91193025/1519830150',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/935194105042362368/e-v_pL7f_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/935194105042362368/e-v_pL7f_normal.jpg',
# ...
#      'default_profile_image': False,
#      'description': 'Canadian Immigrant is a national multimedia platform to help immigrants succeed in Canada by providing the information, inspiration and connections they need.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'canadianimmigrant.ca',
#          'expanded_url': 'http://www.canadianimmigrant.ca',
#          'indices': [0, 22],
#          'url': 'http://t.co/hd9zWVFt9D'}]}},
#      'favourites_count': 341,
#      'follow_request_sent': False,
#      'followers_count': 20594,
#      'following': False,
#      'friends_count': 2193,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 27941496,
#      'id_str': '27941496',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 251,
#      'location': 'Toronto, Ontario, Canada',
#      'name': 'Canadian Immigrant',
#      'notifications': False,
#      'profile_background_color': '3A3A3A',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/601127176004509696/YpODSi6s.png',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/601127176004509696/YpODSi6s.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/27941496/1515697084',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000544005373/c2c786d458bde7631aeecb03310cb356_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000544005373/c2c786d458bde7631aeecb03310cb356_normal.jpeg',
#      'profile_link_color': 'FF0000',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': '363636',
#      'profile_text_color': '393939',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'canimmigrant',
#      'statuses_count': 4744,
#      'time_zone': 'Eastern Time (US & Canada)',
#      'translator_type': 'none',
#      'url': 'http://t.co/hd9zWVFt9D',
#      'utc_offset': -18000,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @canimmigrant: Nominations close TONIGHT!\n\nNominate someone for the 2018 #RBC Canadian Immigrant Awards that shows the positive impact o…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Jun 16 00:04:20 +0000 2009',
#     'default_profile': True,
#     'default_profile_image': True,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 2,
#     'follow_request_sent': False,
#     'followers_count': 3,
#     'following': False,
#     'friends_count': 46,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 47485878,
#     'id_str': '47485878',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': 'Ottawa, Ontario',
#     'name': 'Soojin Yu',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'soojinyu',
#     'statuses_count': 6,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -28800,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Feb 28 23:48:45 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'bbc.com/news/world-us-…',
#       'expanded_url': 'http://www.bbc.com/news/world-us-canada-43230268',
#       'indices': [71, 94],
#       'url': 'https://t.co/jRtJYi582w'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 968996426759000064,
#    'id_str': '968996426759000064',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'text': 'BBC News - Oakland Mayor Libby Schaaf defends immigration raid tip-off https://t.co/jRtJYi582w',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Aug 26 15:09:03 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 1940,
#     'follow_request_sent': False,
#     'followers_count': 394,
#     'following': False,
#     'friends_count': 1857,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 69005894,
#     'id_str': '69005894',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 16,
#     'location': '',
#     'name': 'Pat Pickren',
#     'notifications': False,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1178858389/Animal_Crossing_normal.JPG',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1178858389/Animal_Crossing_normal.JPG',
#     'profile_link_color': '2FC2EF',
#     'profile_sidebar_border_color': '181A1E',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'p_pickren',
#     'statuses_count': 5402,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -18000,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Feb 28 23:48:21 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'fb.me/KuPsnBpp',
#       'expanded_url': 'https://fb.me/KuPsnBpp',
#       'indices': [114, 137],
#       'url': 'https://t.co/n8sWAQTIx0'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 968996325038505985,
#    'id_str': '968996325038505985',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#    'text': 'The Government of Canada has been discussing removing the immigration inadmissibility rule known as “excessive... https://t.co/n8sWAQTIx0',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Feb 12 04:26:09 +0000 2013',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Crightney Immigration offers assistance with temporary & permanent immigration for Canada. Contact us to begin your application.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'crightneyimmigration.com',
#         'expanded_url': 'http://www.crightneyimmigration.com/',
#         'indices': [0, 22],
#         'url': 'http://t.co/FNdpONzAcn'}]}},
#     'favourites_count': 1005,
#     'follow_request_sent': False,
#     'followers_count': 3499,
#     'following': False,
#     'friends_count': 426,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1170888913,
#     'id_str': '1170888913',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 14,
#     'location': 'Canada',
#     'name': 'Canada Immigration',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000669986416/1739082666023c270f0199c9f1d36224_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000669986416/1739082666023c270f0199c9f1d36224_normal.jpeg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'CIS_canada',
#     'statuses_count': 515,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://t.co/FNdpONzAcn',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Feb 28 23:48:17 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 1080324554,
#       'id_str': '1080324554',
#       'indices': [3, 19],
#       'name': 'Air Canada México',
#       'screen_name': 'AirCanadaMexico'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 968996307045109760,
#    'id_str': '968996307045109760',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 3,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Feb 28 14:12:21 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/968851370781564928',
#        'indices': [117, 140],
#        'url': 'https://t.co/iofuucXCu3'}],
#      'user_mentions': []},
#     'favorite_count': 4,
#     'favorited': False,
#     'geo': None,
#     'id': 968851370781564928,
#     'id_str': '968851370781564928',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 3,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'Los ciudadanos mexicanos no necesitan visa para ir a Canadá, No obstante, deberán contar con una Autorización elect… https://t.co/iofuucXCu3',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Jan 11 17:09:41 +0000 2013',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Cuenta oficial de Air Canada México. Call center D.F. 91.38.02.80 / LADA sin costo 01.800.719.28.27.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'aircanada.com/mx/es/home.html',
#          'expanded_url': 'http://www.aircanada.com/mx/es/home.html',
#          'indices': [0, 22],
#          'url': 'http://t.co/IEbl3oNpnJ'}]}},
#      'favourites_count': 1529,
#      'follow_request_sent': False,
#      'followers_count': 1584,
#      'following': False,
#      'friends_count': 330,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 1080324554,
#      'id_str': '1080324554',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'es',
#      'listed_count': 22,
#      'location': 'México, D.F.',
#      'name': 'Air Canada México',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/761267552/148bdbfce675e84cdaff30abe1833f56.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/761267552/148bdbfce675e84cdaff30abe1833f56.jpeg',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1080324554/1504710868',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/830064377474609153/V7pTesmE_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/830064377474609153/V7pTesmE_normal.jpg',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'AirCanadaMexico',
#      'statuses_count': 6419,
#      'time_zone': 'Central Time (US & Canada)',
#      'translator_type': 'none',
#      'url': 'http://t.co/IEbl3oNpnJ',
#      'utc_offset': -21600,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @AirCanadaMexico: Los ciudadanos mexicanos no necesitan visa para ir a Canadá, No obstante, deberán contar con una Autorización electrón…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Sep 04 23:36:41 +0000 2010',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'abogado, ciudad autonoma de buenos aires, fana de river, anti kuka, Pro de la 1ra hora detesto corruptos',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 145237,
#     'follow_request_sent': False,
#     'followers_count': 944,
#     'following': False,
#     'friends_count': 321,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 186987322,
#     'id_str': '186987322',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 26,
#     'location': 'Argentina',
#     'name': 'CARLOS TOLOSA',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/186987322/1434225411',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/956287167067770882/t8ZtpLDu_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/956287167067770882/t8ZtpLDu_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'CARLOSATOLOSA',
#     'statuses_count': 119233,
#     'time_zone': 'Buenos Aires',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -10800,
#     'verified': False}}]}

# %%
# View Search Object
# print(public_tweets)

# Loop through all tweets
for tweet in public_tweets["statuses"]:

    # Utilize JSON dumps to generate a pretty-printed json
    # print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))
    print(tweet["text"])
# Out:
# RT @CARLadvocates: Shameful and a violation of international standards: Immigration detainee Ebrahim Toure marks five years without freedom…
# Oakland Mayor Libby Schaaf defends immigration raid tip-off - BBC News https://t.co/zVTjbyXhkl
# This will blow your mind: mass immigration into Canada and the nonsensical approach behind it..... #cdnpoli https://t.co/DweI2EVRjA
# Powerful video. A rural community realizes the emotional and economic consequences of the Trump immigration crackdo… https://t.co/HcVuIVaf3q
# Doug Saunders’ “Maximum Canada” = Minimum White Canadians: Doug Saunders’s… https://t.co/dA39EVRKxB #immigration
# RT @AirCanadaMexico: Los ciudadanos mexicanos no necesitan visa para ir a Canadá, No obstante, deberán contar con una Autorización electrón…
# Secure Express Entry to Canada without a Canadian job offer. Learn how it's possible with Calver and Associates:… https://t.co/OSB5j2YA2h
# RT @MrsChahine: Ss share their immigration stories and being welcomed to Canada with Canada’s Outstanding Principals @TLPCanada @ThelmaSamb…
# @UniNoticias  @ImmigrationCana has guidelines on how to apply for any situation. Refugee claims, work visas, studen… https://t.co/kZwOV5vzsv
# RT @BFD1982USN: Criminal Oakland Mayor Libby Schaaf defends immigration raid tip-off https://t.co/SastRDlEY5
# RT @CitImmCanada: Keep top international talent in Atlantic Canada. Learn how the Atlantic Immigration Pilot program can benefit your busin…
# RT @canimmigrant: Nominations close TONIGHT!
#
# Nominate someone for the 2018 #RBC Canadian Immigrant Awards that shows the positive impact o…
# BBC News - Oakland Mayor Libby Schaaf defends immigration raid tip-off https://t.co/jRtJYi582w
# The Government of Canada has been discussing removing the immigration inadmissibility rule known as “excessive... https://t.co/n8sWAQTIx0
# RT @AirCanadaMexico: Los ciudadanos mexicanos no necesitan visa para ir a Canadá, No obstante, deberán contar con una Autorización electrón…
