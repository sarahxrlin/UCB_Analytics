# %% [markdown]
# [use counts and not pages](https://developer.twitter.com/en/docs/tweets/timelines/guides/working-with-timelines)

# %%
# Dependencies
import tweepy
import numpy as np

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from config import (consumer_key, 
                    consumer_secret, 
                    access_token, 
                    access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Search for People Tweeting about Kanye West
search_term = "Kanye West"

# Create variable for holding the oldest tweet
oldest_tweet = None

# Save the list of tweets
tweet_array = []

# Loop through 5 times (total of 500 tweets)
for x in range(5):

    # Retrieve 100 most recent tweets -- specifying a max_id
    public_tweets = api.search(search_term, 
                               count=100, 
                               result_type="recent", 
                               max_id=oldest_tweet)

    # Print Tweets
    for tweet in public_tweets["statuses"]:

        # Utilize JSON dumps to generate a pretty-printed json
        # print(json.dumps(
        #     tweet, sort_keys=True, indent=4, separators=(',', ': ')))

        # Add tweets to the tweet array
        tweet_array.append(tweet)
            
        # Print the username
        print(tweet["user"]["screen_name"])

        # Print the tweet id
        print(tweet["id_str"])

        # Print the tweet text
        print(tweet["text"])
        print()

    # Reassign the the oldest tweet (i.e. the max_id)
    # Subtract 1 so the previous oldest isn't included
    # in the new search
    oldest_tweet = int(tweet["id_str"]) -1
# Out:
# RadioOlbiaWeb
# 969727217797353473
# Adesso in onda John Legend - Number One  (featuring Kanye West) https://t.co/LDE9o7mNA5
#
# bdnews24
# 969727191268249600
# Facebook buys Kim Kardashian West celebrity prank show - CNET Commentary: "You Kiddin' Me" is inspired by Kardashia… https://t.co/B93T5F06kr
#
# jman_juan
# 969727161404968960
# RT @GreyMatterrs: Jay Z and Kanye West needs to chill and stop exchanging blows in public https://t.co/dPCSVNEkSq
#
# faa_sht
# 969727155524562945
# Kanye west c’est un chien a pas faire de version clean de pinocchio story la sur spotify on doit se taper des cris des grosseuh folle
#
# RaceToDeath
# 969726885088448514
# This is my favorite Ross track because the production is flawless and all the verses were tough. https://t.co/VtCXq5Lauo
#
# Desi12354
# 969726868826947584
# RT @richthekid: This is missing songs smh.. Where’s Quavo ? Offset ? Kanye West? Frank Ocean?? Take Off ?🤨😒🤔 https://t.co/81zbmFxTf1
#
# chelsscho
# 969726866289393665
# ...

# %%
oldest_tweet
# Out:
# 969697947205201920

# %%
oldest_tweet
# Out:
# 969699999775907839

# %%
# Print total number of tweets
print(len(tweet_array))
# Out:
# 500
