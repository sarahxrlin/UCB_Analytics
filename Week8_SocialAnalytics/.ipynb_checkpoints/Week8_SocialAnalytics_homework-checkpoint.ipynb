# %%
# Dependencies
import tweepy
import numpy as np
from pprint import pprint
import matplotlib.pyplot as plt

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from config import (consumer_key, 
                    consumer_secret, 
                    access_token, 
                    access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
public_tweets = api.search(
            "@BBC", count=20, result_type="recent", max_id=oldest_tweet)

#pprint(public_tweets, indent = 0.5)

for tweet in public_tweets:
    print(pprint(list(public_tweets["statuses"][0].keys())))
# Out:
# ['created_at',
#  'id',
#  'id_str',
#  'text',
#  'truncated',
#  'entities',
#  'extended_entities',
#  'metadata',
#  'source',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'in_reply_to_screen_name',
#  'user',
#  'geo',
#  'coordinates',
#  'place',
#  'contributors',
#  'retweeted_status',
#  'is_quote_status',
#  'retweet_count',
#  'favorite_count',
#  'favorited',
#  'retweeted',
#  'possibly_sensitive',
#  'lang']
# None
# ['created_at',
#  'id',
#  'id_str',
#  'text',
#  'truncated',
#  'entities',
#  'extended_entities',
#  'metadata',
#  'source',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'in_reply_to_screen_name',
#  'user',
#  'geo',
#  'coordinates',
#  'place',
#  'contributors',
#  'retweeted_status',
#  'is_quote_status',
#  'retweet_count',
#  'favorite_count',
#  'favorited',
#  'retweeted',
# ...

# %%
for tweet in public_tweets:
    print(pprint(public_tweets["statuses"][0]))
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Mar 12 01:06:22 +0000 2018',
#  'entities': {'hashtags': [{'indices': [61, 68], 'text': 'BBCdad'}],
#               'media': [{'display_url': 'pic.twitter.com/Q5I70XxT7T',
#                          'expanded_url': 'https://twitter.com/BBC/status/972381291143249920/video/1',
#                          'id': 943157249815535618,
#                          'id_str': '943157249815535618',
#                          'indices': [69, 92],
#                          'media_url': 'http://pbs.twimg.com/amplify_video_thumb/943157249815535618/img/5-h8Kq3WNlXWnRfT.jpg',
#                          'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/943157249815535618/img/5-h8Kq3WNlXWnRfT.jpg',
#                          'sizes': {'large': {'h': 720,
#                                              'resize': 'fit',
#                                              'w': 1280},
# ...

# %%
# for tweet in public_tweets:
#     print(pprint(public_tweets["statuses"][0].keys()))
    
first = public_tweets["statuses"][0]

for k,v in first.items():
    print(k, v)
# Out:
# created_at Mon Mar 12 01:06:22 +0000 2018
# id 973002225575395328
# id_str 973002225575395328
# text RT @BBC: 🙌 1 year ago today the world became a better place.
# #BBCdad https://t.co/Q5I70XxT7T
# truncated False
# ...

# %%
# Target Search Term
# BBC, CBS, CNN, Fox, and New York times
target_terms = ("@BBC", "@CBS", "@FoxNews", "@nytimes")

# Array to hold sentiment
sentiment_array = []

# Loop through all target users
for target in target_terms:

    # Variable for holding the oldest tweet
    oldest_tweet = None

    # Variables for holding sentiments
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []

    # make multiple requests
    for x in range(5):

        # Run search around each tweet
        public_tweets = api.search(
            target, count=20, result_type="recent", max_id=oldest_tweet)

        # Loop through all tweets
        for tweet in public_tweets["statuses"]:

                # Run Vader Analysis on each tweet
                results = analyzer.polarity_scores(tweet["text"])
                compound = results["compound"]
                pos = results["pos"]
                neu = results["neu"]
                neg = results["neg"]

                # Add each value to the appropriate array
                compound_list.append(compound)
                positive_list.append(pos)
                negative_list.append(neg)
                neutral_list.append(neu)
                
        # Set the new oldest_tweet value
        oldest_tweet = int(tweet["id_str"]) - 1

    # Store the Average Sentiments
    sentiment_array.append({
        "User": target,
        "Compound": np.mean(compound_list),
        "Positive": np.mean(positive_list),
        "Neutral": np.mean(negative_list),
        "Negative": np.mean(neutral_list),
        "Tweet Count": len(compound_list)
    })

    # Print the Sentiments
    print(sentiment_array)
    print()
# Out:
# [{'User': '@BBC', 'Compound': 0.0, 'Positive': 0.0, 'Neutral': 1.0, 'Negative': 0.0, 'Tweet Count': 0}]
#
# [{'User': '@BBC', 'Compound': 0.0, 'Positive': 0.0, 'Neutral': 1.0, 'Negative': 0.0, 'Tweet Count': 0}, {'User': '@CBS', 'Compound': 0.4019, 'Positive': 0.184, 'Neutral': 0.816, 'Negative': 0.0, 'Tweet Count': 0}]
#
# [{'User': '@BBC', 'Compound': 0.0, 'Positive': 0.0, 'Neutral': 1.0, 'Negative': 0.0, 'Tweet Count': 0}, {'User': '@CBS', 'Compound': 0.4019, 'Positive': 0.184, 'Neutral': 0.816, 'Negative': 0.0, 'Tweet Count': 0}, {'User': '@FoxNews', 'Compound': -0.6597, 'Positive': 0.0, 'Neutral': 0.735, 'Negative': 0.265, 'Tweet Count': 0}]
#
# ...
